# %% [markdown]
# # RandomForest with HyperTuning concept:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("insurance_pre.csv")
data.head(5)
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
df = pd.get_dummies(data,drop_first = True,dtype=int)

# %%
independent = df[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent = df[["charges"]]

# %%
independent.head(5)
# Out:
#    age     bmi  children  sex_male  smoker_yes
# 0   19  27.900         0         0           1
# 1   18  33.770         1         1           0
# 2   28  33.000         3         1           0
# 3   33  22.705         0         1           0
# 4   32  28.880         0         1           0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
'max_features': ['sqrt','log2'],
'n_estimators':[10,50,100,250,500]}

# %%
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100, 250, 500]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
re=grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.029226      0.004674         0.005828        0.003075
# 1        0.130732      0.014040         0.006727        0.004181
# 2        0.254136      0.005190         0.009576        0.003836
# 3        0.646380      0.018001         0.026699        0.004780
# 4        1.252932      0.017004         0.045669        0.004206
# 5        0.024579      0.003068         0.002862        0.003548
# 6        0.125008      0.004112         0.004744        0.004470
# 7        0.246832      0.003808         0.011267        0.001282
# 8        0.631345      0.014186         0.024307        0.005700
# 9        1.264858      0.039117         0.046949        0.003795
# 10       0.094499      0.020682         0.010756        0.013712
# 11       0.377149      0.008967         0.004626        0.004103
# 12       0.763295      0.006357         0.010132        0.004388
# 13       1.932745      0.034789         0.024217        0.003840
# 14       3.860248      0.023841         0.038845        0.003888
# 15       0.081118      0.012083         0.005579        0.003908
# 16       0.377407      0.003838         0.006461        0.000891
# 17       0.759351      0.010638         0.011878        0.004263
# 18       1.904293      0.013445         0.021592        0.002833
# 19       3.961633      0.132836         0.045893        0.008299
# 20       0.022365      0.005038         0.000502        0.001005
# 21       0.118294      0.003675         0.006556        0.002478
# 22       0.244468      0.006984         0.009800        0.005202
# 23       0.677068      0.029060         0.026389        0.004608
# 24       1.537583      0.039532         0.058004        0.006339
# 25       0.033446      0.005950         0.003211        0.004184
# 26       0.150671      0.006548         0.011163        0.006500
# 27       0.326226      0.026892         0.011368        0.004272
# 28       0.749617      0.020071         0.028500        0.005138
# 29       1.531513      0.017884         0.051496        0.002946
# 30       0.037098      0.004358         0.003760        0.003105
# 31       0.173576      0.012896         0.004955        0.004208
# 32       0.334990      0.013275         0.012946        0.005409
# 33       0.802354      0.017100         0.028160        0.005887
# 34       1.675045      0.044876         0.055653        0.006813
# 35       0.038249      0.004744         0.000599        0.001197
# 36       0.167366      0.008590         0.008399        0.005828
# 37       0.324046      0.011287         0.011115        0.002379
# 38       0.721016      0.029485         0.022741        0.005055
# 39       1.348985      0.099947         0.037371        0.005474
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                100
# 3    squared_error               sqrt                250
# 4    squared_error               sqrt                500
# 5    squared_error               log2                 10
# 6    squared_error               log2                 50
# 7    squared_error               log2                100
# 8    squared_error               log2                250
# 9    squared_error               log2                500
# 10  absolute_error               sqrt                 10
# 11  absolute_error               sqrt                 50
# 12  absolute_error               sqrt                100
# 13  absolute_error               sqrt                250
# 14  absolute_error               sqrt                500
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18  absolute_error               log2                250
# 19  absolute_error               log2                500
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                 50
# 22    friedman_mse               sqrt                100
# 23    friedman_mse               sqrt                250
# 24    friedman_mse               sqrt                500
# 25    friedman_mse               log2                 10
# 26    friedman_mse               log2                 50
# 27    friedman_mse               log2                100
# 28    friedman_mse               log2                250
# 29    friedman_mse               log2                500
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                 50
# 32         poisson               sqrt                100
# 33         poisson               sqrt                250
# 34         poisson               sqrt                500
# 35         poisson               log2                 10
# 36         poisson               log2                 50
# 37         poisson               log2                100
# 38         poisson               log2                250
# 39         poisson               log2                500
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.843222
# 1   {'criterion': 'squared_error', 'max_features':...           0.863989
# 2   {'criterion': 'squared_error', 'max_features':...           0.869865
# 3   {'criterion': 'squared_error', 'max_features':...           0.864806
# 4   {'criterion': 'squared_error', 'max_features':...           0.868430
# 5   {'criterion': 'squared_error', 'max_features':...           0.844345
# 6   {'criterion': 'squared_error', 'max_features':...           0.861356
# 7   {'criterion': 'squared_error', 'max_features':...           0.867195
# 8   {'criterion': 'squared_error', 'max_features':...           0.866004
# 9   {'criterion': 'squared_error', 'max_features':...           0.865029
# 10  {'criterion': 'absolute_error', 'max_features'...           0.827655
# 11  {'criterion': 'absolute_error', 'max_features'...           0.865278
# 12  {'criterion': 'absolute_error', 'max_features'...           0.861403
# 13  {'criterion': 'absolute_error', 'max_features'...           0.861340
# 14  {'criterion': 'absolute_error', 'max_features'...           0.860658
# 15  {'criterion': 'absolute_error', 'max_features'...           0.828112
# 16  {'criterion': 'absolute_error', 'max_features'...           0.858539
# 17  {'criterion': 'absolute_error', 'max_features'...           0.861543
# 18  {'criterion': 'absolute_error', 'max_features'...           0.863124
# 19  {'criterion': 'absolute_error', 'max_features'...           0.861845
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.845827
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.853174
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.859549
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.867042
# 24  {'criterion': 'friedman_mse', 'max_features': ...           0.866843
# 25  {'criterion': 'friedman_mse', 'max_features': ...           0.842381
# 26  {'criterion': 'friedman_mse', 'max_features': ...           0.854766
# 27  {'criterion': 'friedman_mse', 'max_features': ...           0.861694
# 28  {'criterion': 'friedman_mse', 'max_features': ...           0.867894
# 29  {'criterion': 'friedman_mse', 'max_features': ...           0.864535
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.827182
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.855609
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.866905
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...           0.862904
# 34  {'criterion': 'poisson', 'max_features': 'sqrt...           0.865683
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.836489
# 36  {'criterion': 'poisson', 'max_features': 'log2...           0.863677
# 37  {'criterion': 'poisson', 'max_features': 'log2...           0.859878
# 38  {'criterion': 'poisson', 'max_features': 'log2...           0.864973
# 39  {'criterion': 'poisson', 'max_features': 'log2...           0.865198
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.770261           0.795139           0.802967
# 1            0.791480           0.807144           0.838079
# 2            0.790473           0.811523           0.831499
# 3            0.790494           0.812297           0.830479
# 4            0.793898           0.809587           0.830140
# 5            0.750236           0.786855           0.809317
# 6            0.780335           0.810294           0.823061
# 7            0.789617           0.800936           0.827580
# 8            0.792501           0.806083           0.825907
# 9            0.794027           0.811440           0.829627
# 10           0.762767           0.789418           0.816324
# 11           0.785125           0.800750           0.826941
# 12           0.791696           0.807851           0.824341
# 13           0.794886           0.811766           0.823661
# 14           0.794103           0.811383           0.826765
# 15           0.788672           0.802588           0.807690
# 16           0.787416           0.810115           0.827425
# 17           0.793750           0.805786           0.823294
# 18           0.796184           0.811884           0.829732
# 19           0.795119           0.812573           0.825187
# 20           0.773751           0.785198           0.799396
# 21           0.776956           0.814359           0.809388
# 22           0.791364           0.814425           0.825925
# 23           0.793426           0.810677           0.829305
# 24           0.792389           0.807605           0.829495
# 25           0.756273           0.787402           0.817106
# 26           0.791702           0.805043           0.819446
# 27           0.786419           0.814016           0.830860
# 28           0.792699           0.807717           0.830115
# 29           0.793762           0.809818           0.828018
# 30           0.778024           0.765983           0.799212
# 31           0.787363           0.805491           0.818774
# 32           0.791547           0.806047           0.830087
# 33           0.795098           0.805660           0.828350
# 34           0.793300           0.810462           0.829181
# 35           0.771575           0.794527           0.807860
# 36           0.792445           0.813396           0.826941
# 37           0.791719           0.805669           0.833881
# 38           0.792073           0.812580           0.827784
# 39           0.795866           0.811692           0.829116
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.752976         0.792913        0.030806               35
# 1            0.763083         0.812755        0.035264               16
# 2            0.771862         0.815045        0.033932                1
# 3            0.772490         0.814113        0.032035                7
# 4            0.769789         0.814369        0.033468                5
# 5            0.758146         0.789780        0.034444               38
# 6            0.765737         0.808157        0.033557               30
# 7            0.768183         0.810702        0.034130               26
# 8            0.770614         0.812222        0.032365               20
# 9            0.771456         0.814316        0.031822                6
# 10           0.765013         0.792236        0.026276               36
# 11           0.778002         0.811219        0.031823               25
# 12           0.771235         0.811305        0.030600               24
# 13           0.770586         0.812448        0.030257               19
# 14           0.770355         0.812653        0.030458               17
# 15           0.771595         0.799731        0.018926               33
# 16           0.763800         0.809459        0.032566               28
# 17           0.766950         0.810265        0.031522               27
# 18           0.773757         0.814936        0.030324                2
# 19           0.771119         0.813169        0.030358               14
# 20           0.747385         0.790312        0.032581               37
# 21           0.769065         0.804588        0.030015               32
# 22           0.769356         0.812124        0.030676               21
# 23           0.771498         0.814390        0.032520                4
# 24           0.770388         0.813344        0.032986               13
# 25           0.762693         0.793171        0.032613               34
# 26           0.770242         0.808240        0.028347               29
# 27           0.770052         0.812608        0.032377               18
# 28           0.769853         0.813656        0.033484               10
# 29           0.771615         0.813549        0.031537               11
# 30           0.746098         0.783300        0.027894               40
# 31           0.765987         0.806645        0.030235               31
# 32           0.769782         0.812874        0.033389               15
# 33           0.768255         0.812053        0.031931               22
# 34           0.770156         0.813756        0.032449                9
# 35           0.720712         0.786233        0.038911               39
# 36           0.770339         0.813360        0.031637               12
# 37           0.766651         0.811560        0.032490               23
# 38           0.771682         0.813819        0.031817                8
# 39           0.772019         0.814778        0.031443                3

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2score = r2_score(y_test,y_pred)
r2score
# Out:
# 0.8690950769852043

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 19
# BMI: 27.900
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
new_data = [[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]
# IMPORTANT: Use transform(), NOT fit_transform()
new_data_scaled = sc.transform(new_data)  
print(new_data_scaled)
# Out:
# [[-1.46169465 -0.45767803 -0.89833872 -0.97676557  1.98149332]]

# %%
# Make prediction using trained model
Future_Prediction = grid.predict(new_data_scaled)

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[17241.981491]
