# %% [markdown]
# # RandomForest with HyperTuning GridSearchCV concept:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("insurance_pre.csv")
data.head(5)
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
df = pd.get_dummies(data,drop_first = True,dtype=int)

# %%
independent = df[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent = df[["charges"]]

# %%
independent.head(5)
# Out:
#    age     bmi  children  sex_male  smoker_yes
# 0   19  27.900         0         0           1
# 1   18  33.770         1         1           0
# 2   28  33.000         3         1           0
# 3   33  22.705         0         1           0
# 4   32  28.880         0         1           0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
#Foe Input data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#For output data
scy = StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
'max_features': ['sqrt','log2'],
'n_estimators':[10,50,100,250,500]}

# %%
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100, 250, 500]},
#              verbose=3)

# %%
print(grid.best_params_)
#For deployment phase - create pkl file with best_model name
best_model = grid.best_estimator_
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 50}

# %%
re=grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.033434      0.003267         0.002052        0.002990
# 1        0.122247      0.002603         0.008998        0.001912
# 2        0.268780      0.019480         0.012586        0.003402
# 3        1.523258      0.166367         0.057352        0.004644
# 4        3.390945      0.047954         0.111440        0.013381
# 5        0.072094      0.003574         0.005604        0.004590
# 6        0.332207      0.012976         0.013706        0.003037
# 7        0.676125      0.017132         0.022298        0.002272
# 8        1.669551      0.069990         0.058954        0.003826
# 9        3.462530      0.049562         0.110930        0.005707
# 10       0.211889      0.005958         0.004504        0.004430
# 11       1.041404      0.012774         0.012142        0.004047
# 12       2.066500      0.032703         0.019219        0.003051
# 13       5.163043      0.083467         0.054206        0.004642
# 14      10.064722      0.092996         0.106873        0.007561
# 15       0.199796      0.011392         0.007002        0.002281
# 16       1.006601      0.006243         0.013069        0.002094
# 17       1.995809      0.029661         0.020731        0.003223
# 18       5.033359      0.084485         0.050710        0.006379
# 19       9.675812      0.049206         0.107991        0.009751
# 20       0.074436      0.011101         0.006912        0.004485
# 21       0.330857      0.021523         0.014566        0.004149
# 22       0.636292      0.026195         0.020597        0.003945
# 23       1.640471      0.055544         0.053272        0.011450
# 24       3.363502      0.039485         0.112228        0.006983
# 25       0.071496      0.003623         0.002822        0.002760
# 26       0.339484      0.007055         0.014310        0.003039
# 27       0.690565      0.011411         0.022152        0.001509
# 28       1.694089      0.016780         0.059872        0.002474
# 29       3.145701      0.361407         0.100848        0.012981
# 30       0.002641      0.002427         0.000000        0.000000
# 31       0.000643      0.001286         0.000000        0.000000
# 32       0.002529      0.001197         0.000000        0.000000
# 33       0.003204      0.001458         0.000000        0.000000
# 34       0.001956      0.001884         0.000000        0.000000
# 35       0.003432      0.003219         0.000000        0.000000
# 36       0.002198      0.003206         0.000000        0.000000
# 37       0.000693      0.000849         0.000000        0.000000
# 38       0.001715      0.001418         0.000000        0.000000
# 39       0.001668      0.001290         0.000000        0.000000
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                100
# 3    squared_error               sqrt                250
# 4    squared_error               sqrt                500
# 5    squared_error               log2                 10
# 6    squared_error               log2                 50
# 7    squared_error               log2                100
# 8    squared_error               log2                250
# 9    squared_error               log2                500
# 10  absolute_error               sqrt                 10
# 11  absolute_error               sqrt                 50
# 12  absolute_error               sqrt                100
# 13  absolute_error               sqrt                250
# 14  absolute_error               sqrt                500
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18  absolute_error               log2                250
# 19  absolute_error               log2                500
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                 50
# 22    friedman_mse               sqrt                100
# 23    friedman_mse               sqrt                250
# 24    friedman_mse               sqrt                500
# 25    friedman_mse               log2                 10
# 26    friedman_mse               log2                 50
# 27    friedman_mse               log2                100
# 28    friedman_mse               log2                250
# 29    friedman_mse               log2                500
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                 50
# 32         poisson               sqrt                100
# 33         poisson               sqrt                250
# 34         poisson               sqrt                500
# 35         poisson               log2                 10
# 36         poisson               log2                 50
# 37         poisson               log2                100
# 38         poisson               log2                250
# 39         poisson               log2                500
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.850694
# 1   {'criterion': 'squared_error', 'max_features':...           0.865944
# 2   {'criterion': 'squared_error', 'max_features':...           0.861882
# 3   {'criterion': 'squared_error', 'max_features':...           0.863913
# 4   {'criterion': 'squared_error', 'max_features':...           0.862846
# 5   {'criterion': 'squared_error', 'max_features':...           0.841969
# 6   {'criterion': 'squared_error', 'max_features':...           0.858078
# 7   {'criterion': 'squared_error', 'max_features':...           0.863790
# 8   {'criterion': 'squared_error', 'max_features':...           0.863157
# 9   {'criterion': 'squared_error', 'max_features':...           0.863266
# 10  {'criterion': 'absolute_error', 'max_features'...           0.846349
# 11  {'criterion': 'absolute_error', 'max_features'...           0.864669
# 12  {'criterion': 'absolute_error', 'max_features'...           0.863664
# 13  {'criterion': 'absolute_error', 'max_features'...           0.864587
# 14  {'criterion': 'absolute_error', 'max_features'...           0.865662
# 15  {'criterion': 'absolute_error', 'max_features'...           0.872129
# 16  {'criterion': 'absolute_error', 'max_features'...           0.865389
# 17  {'criterion': 'absolute_error', 'max_features'...           0.859379
# 18  {'criterion': 'absolute_error', 'max_features'...           0.865212
# 19  {'criterion': 'absolute_error', 'max_features'...           0.865686
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.853998
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.861207
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.863319
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.862089
# 24  {'criterion': 'friedman_mse', 'max_features': ...           0.863608
# 25  {'criterion': 'friedman_mse', 'max_features': ...           0.840867
# 26  {'criterion': 'friedman_mse', 'max_features': ...           0.860663
# 27  {'criterion': 'friedman_mse', 'max_features': ...           0.859784
# 28  {'criterion': 'friedman_mse', 'max_features': ...           0.862384
# 29  {'criterion': 'friedman_mse', 'max_features': ...           0.864529
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 34  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 35  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 36  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 37  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 38  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 39  {'criterion': 'poisson', 'max_features': 'log2...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.836347           0.747739           0.786767
# 1            0.861701           0.762137           0.809068
# 2            0.868131           0.749720           0.796034
# 3            0.866506           0.757944           0.802803
# 4            0.867024           0.758416           0.799033
# 5            0.851088           0.734257           0.762297
# 6            0.863824           0.756319           0.796431
# 7            0.870403           0.759025           0.797823
# 8            0.867145           0.760812           0.799607
# 9            0.865679           0.761442           0.801099
# 10           0.849810           0.736566           0.785475
# 11           0.857130           0.753695           0.797369
# 12           0.862051           0.753194           0.799022
# 13           0.862552           0.755308           0.800220
# 14           0.862933           0.751963           0.800773
# 15           0.847250           0.710645           0.794240
# 16           0.865504           0.747382           0.792642
# 17           0.863392           0.756324           0.793297
# 18           0.865705           0.749252           0.803526
# 19           0.867603           0.755730           0.799943
# 20           0.847400           0.737625           0.779270
# 21           0.865341           0.751906           0.791736
# 22           0.866804           0.760355           0.799607
# 23           0.867268           0.753300           0.799235
# 24           0.866914           0.762812           0.798990
# 25           0.851687           0.707754           0.771843
# 26           0.861842           0.758961           0.800236
# 27           0.867473           0.759802           0.798228
# 28           0.863262           0.758802           0.797603
# 29           0.868313           0.760404           0.798628
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32                NaN                NaN                NaN
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
# 36                NaN                NaN                NaN
# 37                NaN                NaN                NaN
# 38                NaN                NaN                NaN
# 39                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.775352         0.799380        0.038478               28
# 1            0.809336         0.821637        0.038517                1
# 2            0.813463         0.817846        0.043827               15
# 3            0.811238         0.820481        0.040776                5
# 4            0.810655         0.819595        0.040904                8
# 5            0.779078         0.793738        0.045512               30
# 6            0.804369         0.815804        0.040342               20
# 7            0.804329         0.819074        0.042212               10
# 8            0.810417         0.820228        0.040239                7
# 9            0.811094         0.820516        0.039555                4
# 10           0.801142         0.803869        0.041930               25
# 11           0.805139         0.815601        0.041004               21
# 12           0.799757         0.815538        0.042162               22
# 13           0.804961         0.817526        0.041402               17
# 14           0.806710         0.817608        0.042603               16
# 15           0.788396         0.802532        0.055777               26
# 16           0.801854         0.814554        0.045461               24
# 17           0.804265         0.815332        0.040841               23
# 18           0.806291         0.817997        0.043767               14
# 19           0.808100         0.819412        0.042488                9
# 20           0.782257         0.800110        0.044267               27
# 21           0.810849         0.816208        0.042898               19
# 22           0.813874         0.820792        0.040187                3
# 23           0.808270         0.818032        0.042436               13
# 24           0.812926         0.821050        0.039646                2
# 25           0.798108         0.794052        0.051905               29
# 26           0.805319         0.817404        0.039249               18
# 27           0.805335         0.818124        0.040328               12
# 28           0.808627         0.818136        0.040067               11
# 29           0.810022         0.820379        0.041047                6
# 30                NaN              NaN             NaN               31
# 31                NaN              NaN             NaN               31
# 32                NaN              NaN             NaN               31
# 33                NaN              NaN             NaN               31
# 34                NaN              NaN             NaN               31
# 35                NaN              NaN             NaN               31
# 36                NaN              NaN             NaN               31
# 37                NaN              NaN             NaN               31
# 38                NaN              NaN             NaN               31
# 39                NaN              NaN             NaN               31

# %% [markdown]
# ## Save the model using PKL file:

# %%
import pickle
filename = "rf_grid.sav"

# %%
#model creation
pickle.dump(best_model,open(filename,'wb'))

# %%
#for pre-process for X_data
pickle.dump(sc,open("X_preprocess_scaler.sav",'wb'))

# %%
#for pre-process for y_data
pickle.dump(scy,open("Y_preprocess_scaler.sav",'wb'))
