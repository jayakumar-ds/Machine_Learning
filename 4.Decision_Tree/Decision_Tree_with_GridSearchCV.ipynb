# %% [markdown]
# # Decision Tree Regressor

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("insurance_pre.csv")
data.head(5)
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
df = pd.get_dummies(data,drop_first = True,dtype=int)

# %%
independent = df[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent = df[["charges"]]

# %%
independent.head(5)
# Out:
#    age     bmi  children  sex_male  smoker_yes
# 0   19  27.900         0         0           1
# 1   18  33.770         1         1           0
# 2   28  33.000         3         1           0
# 3   33  22.705         0         1           0
# 4   32  28.880         0         1           0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['mse','mae','friedman_mse'],
'max_features': ['auto','sqrt','log2'],
'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2score = r2_score(y_test,y_pred)
r2score
# Out:
# 0.7158822100985474

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}

# %%
re=grid.cv_results_
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.000602      0.000738         0.000000        0.000000
# 3        0.000000      0.000000         0.000000        0.000000
# 4        0.000000      0.000000         0.000000        0.000000
# 5        0.001441      0.002882         0.000000        0.000000
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.002001      0.004001         0.000000        0.000000
# 8        0.002001      0.004001         0.000000        0.000000
# 9        0.000993      0.001034         0.000000        0.000000
# 10       0.001239      0.001251         0.000000        0.000000
# 11       0.000987      0.001004         0.000000        0.000000
# 12       0.000799      0.001598         0.000000        0.000000
# 13       0.001215      0.002430         0.000000        0.000000
# 14       0.002791      0.002353         0.001915        0.002349
# 15       0.002220      0.002723         0.003010        0.004134
# 16       0.002097      0.004193         0.004075        0.004995
# 17       0.005703      0.004656         0.001901        0.003802
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 1   {'criterion': 'mse', 'max_features': 'auto', '...                NaN
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...                NaN
# 4   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 5   {'criterion': 'mse', 'max_features': 'log2', '...                NaN
# 6   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 7   {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 10  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 11  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.413029
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.661998
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.654426
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.733013
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.665411           0.671724           0.679215
# 15           0.610682           0.527241           0.589226
# 16           0.660941           0.614355           0.652118
# 17           0.451662           0.644107           0.507876
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                5
# 1                 NaN              NaN             NaN                5
# 2                 NaN              NaN             NaN                5
# 3                 NaN              NaN             NaN                5
# 4                 NaN              NaN             NaN                5
# 5                 NaN              NaN             NaN                5
# 6                 NaN              NaN             NaN                5
# 7                 NaN              NaN             NaN                5
# 8                 NaN              NaN             NaN                5
# 9                 NaN              NaN             NaN                5
# 10                NaN              NaN             NaN                5
# 11                NaN              NaN             NaN                5
# 12                NaN              NaN             NaN                5
# 13                NaN              NaN             NaN                5
# 14           0.602163         0.606309        0.100461                3
# 15           0.644787         0.606787        0.047209                2
# 16           0.558913         0.628151        0.038273                1
# 17           0.476928         0.562717        0.108005                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 19
# BMI: 27.900
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
new_data = [[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]
# IMPORTANT: Use transform(), NOT fit_transform()
new_data_scaled = sc.transform(new_data)  
print(new_data_scaled)
# Out:
# [[-1.46169465 -0.45767803 -0.89833872 -0.97676557  1.98149332]]

# %%
# Make prediction using trained model
Future_Prediction = grid.predict(new_data_scaled)

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16884.924]
